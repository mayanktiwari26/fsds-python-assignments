# %%
"""
Question 1. In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
* 
'hello'
-87.8
- 
/ 
+
6 

# Answer 1.


*      (epresiion)
'hello'(value)
-87.8  (value)
-      (expression)
/      (expression)
+      (expression)
6      (value)

=============================================
Question 2. What is the difference between string and variable?


#Answer 2

A string is a sequence of characters eg. "hello", "what is your name", "1234" etc. whereas a variable is a name given to a computer memory location
which are used to store values in a computer program. A variable can be of any data type such as string, integer, float etc. eg. age = 26 (here age is a variable of type integer ).

========================
Question 3. Describe three different data types.


# Answer 3

Three data types can be -
INTEGER- numbers without a fractional component (eg. 1,10,345)
STRING- combination or sequence of characters  ("hello", "q@23")
BOOLEAN- one of two possible values True or False

============================
Question 4. What is an expression made up of? What do all expressions do?

#Answer 4

An expression is an instruction that combines variables, values and operators that yields a result value.
eg. 5+2, 2*3 , a + b-2 etc

All expressions represent a value
eg. 5+2 - represents value 7

=========================
Question 5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?


#Answer 5

An expression evaluates a value and a statement represents an action or command. for eg. above statement spam = 10 reprensents the action of 
storing value 10 in spam variable.

==============================
Question 6. After running the following code, what does the variable bacon contain?
bacon = 22
bacon + 1

#Answer 6

bacon contains value 22

================================
Question 7. What should the values of the following two terms be?
'spam' + 'spamspam'
'spam' * 3

#Answer 7

'spam' + 'spamspam'  = spamspamspam

'spam' * 3 = spamspamspam

================================
Question 8. Why is eggs a valid variable name while 100 is invalid?


#Answer 8 

variable name should only start either with a character or _(underscore) hence,
eggs is a valid variable name as it starts with a character and 100 is not a valid variable name as it starts with an integer.

==============================
Question 9. What three functions can be used to get the integer, floating-point number, or string version of a value?


#Answer 9

int, str and float functions can be used 

================================
Question 10. Why does this expression cause an error? How can you fix it?
'I have eaten ' + 99 + ' burritos.'

#Answer 10

'I have eaten ' + 99 + ' burritos.

the above expression gives an error as it is trying to concatenate string with an integer which is not allowed in python.
to fix this issue we can convert 99 into a string "99" and then concatenate it.

"""
