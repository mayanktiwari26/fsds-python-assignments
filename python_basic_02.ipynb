# %%
'''
1.What are the two values of the Boolean data type? How do you write them?

Answer1.

True 
False

===========================


2. What are the three different types of Boolean operators?

Answer2.

AND, OR, NOT
=========================

3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).

Answer3.

AND operator
  False and False = False
  False and True  = False
  True and False  = False
  True and True   = True

OR operator
  False or False  = False
  False or True   = True
  True  or False  = True
  True  or True   = True

NOT operator
  not(False) = True
  not(True) = False

=================================

4. What are the values of the following expressions?
(5 > 4) and (3 == 5)
not (5 > 4)
(5 > 4) or (3 == 5)
not ((5 > 4) or (3 == 5))
(True and True) and (True == False)
(not False) or (not True)

Answer 4.

(5 > 4) and (3 == 5)
False

not (5 > 4)
False

(5 > 4) or (3 == 5)
True

not ((5 > 4) or (3 == 5))
False

(True and True) and (True == False)
False

(not False) or (not True)
True

===============================

5. What are the six comparison operators?

Answer5.

six comparison operators are

greater than(>)
greater than or equal to(>=)
lesser than(<)
lesser than or equal to(<=)
equal to (==)
not equal to(!=)

==============================

6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.

Answer 6.

Equal to is == and assignment operator is =

to assign a value 5 to a variable cat and value 6 to variable dog 
cat = 5
dog = 6

now to check whether they are equal or not 

dog == cat

this will give output False

=====================================

7. Identify the three blocks in this code:
spam = 0
if spam == 10:
print('eggs')
if spam > 5:
print('bacon')
else:
print('ham')
print('spam')
print('spam')

Answer7.

the 3 blocks are shown through indentation below

spam = 0
if spam == 10:
  print('eggs')
if spam > 5:
  print('bacon')
else:
  print('ham')
  print('spam')
  print('spam')

==============================================

8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam.

Answer8.

if spam == 1:
  print("Hello")
elif spam == 2:
  print("Howdy")
else:
  print("Greetings!")

========================================

9.If your programme is stuck in an endless loop, what keys you’ll press?

Answer9.
CTRL + C

=================================

10. How can you tell the difference between break and continue?
Answer10.

Break terminates the execution of current loop and passes the control over the next loop or main body.
continue skips the current iteration and executes the next iteration in the loop.

========================================

11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

Answer11.

All 3 are same

===================

12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.
Answer12.

#using for
for i in range(1,11):
  print (i)

# using while
i=1
while i <=10:
  print (i)
  i = i+1


===================================
13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?

Answer13.

spam.bacon()


'''
# Out:
# "\n1.What are the two values of the Boolean data type? How do you write them?\n\nAnswer1.\n\nTrue \nFalse\n\n===========================\n\n\n2. What are the three different types of Boolean operators?\n\nAnswer2.\n\nAND, OR, NOT\n=========================\n\n3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).\n\nAnswer3.\n\nAND operator\n  False and False = False\n  False and True  = False\n  True and False  = False\n  True and True   = True\n\nOR operator\n  False or False  = False\n  False or True   = True\n  True  or False  = True\n  True  or True   = True\n\nNOT operator\n  not(False) = True\n  not(True) = False\n\n=================================\n\n4. What are the values of the following expressions?\n(5 > 4) and (3 == 5)\nnot (5 > 4)\n(5 > 4) or (3 == 5)\nnot ((5 > 4) or (3 == 5))\n(True and True) and (True == False)\n(not False) or (not True)\n\nAnswer 4.\n\n(5 > 4) and (3 == 5)\n
# ...
