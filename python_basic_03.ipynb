# %%
'''
1. Why are functions advantageous to have in your programs?

Answer1. Functions are advantageous as they increase program readability, avoid  repetition, converts complex problem into simple one, reduces chance of error and makes it easier to modify the program.

2. When does the code in a function run: when it is specified or when it is called?

Answer2. code in a function runs when it is called.

3. What statement creates a function?

Answer3. def functionName(arguments):

4. What is the difference between a function and a function call?

Answer4. We define functions to perform a particular task, a function call is basically a way to call that function in order to perform the task.
eg. # function Sum to add two numbers
    def Sum(a,b):
      return a+b
    # now to use Sum function we will call it using function call
    Sum(1,2)
    # this will return value 3

5. How many global scopes are there in a Python program? How many local scopes?

Answer5. A python program has only one global scope and can have any no. of local scopes. 

6. What happens to variables in a local scope when the function call returns?

Answer6. After the function call returns the variable is gone and the memory is assigned to some other variable.

eg. in above Sum(a,b): function if we check the address of variable 'a' outside the function it will throw error.

7. What is the concept of a return value? Is it possible to have a return value in an expression?

Answer7. A return is a value that a function returns to the calling script or function when it completes its task. 
A return value can be any one of the four variable types: handle, integer, object, or string. 
The type of value your function returns depends largely on the task it performs.

Yes it can be in the form of expression

8. If a function does not have a return statement, what is the return value of a call to that function?

Answer8. If a function doesn't have return value statement it returns 'None'

9. How do you make a function variable refer to the global variable?

Answer9. Any global variable can be used inside a function to refer it use the same name.

10. What is the data type of None?

Answer10. NoneType

11. What does the sentence import areallyourpetsnamederic do?

Answer11. It will throw a ModuleNotFoundError if you dont have any module by the same name in your current working directory,
if you have it will import that module.

12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

Answer12. spam.bacon()

13. What can you do to save a programme from crashing if it encounters an error?

Answer13. Error handling

14. What is the purpose of the try clause? What is the purpose of the except clause?

Answer14. we keep that code inside try clause which might throw error and handle that error inside except clause.

'''
